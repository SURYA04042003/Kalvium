# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file
file_path = '/content/election_results_kerala.xlsx'
df = pd.read_excel(file_path)

# Display the DataFrame
print(df)

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a bar chart for the total seats won by each party
plt.bar(df['Party'], df['Total'], color=df['Color'])

# Add labels and title
plt.xlabel('Party')
plt.ylabel('Total Seats Won')
plt.title('Total Seats Won by Each Party in Kerala (2024)')
plt.xticks(rotation=45)

# Display the bar chart
plt.show()

# Set the figure size for the pie chart
plt.figure(figsize=(10, 6))

# Create a pie chart for the vote share of each party
plt.pie(df['Vote Share (%)'], labels=df['Party'], colors=df['Color'], autopct='%1.1f%%', startangle=140)

# Add title
plt.title('Vote Share of Each Party in Kerala (2024)')

# Display the pie chart
plt.show()
# Out:
#     Party  Won  Leading  Total  Vote Share (%)  Vote Count    Color
# 0     INC   14        0     14           35.06     6927111  #19AAED
# 1    IUML    2        0      2            6.07     1199839  #006600
# 2  CPI(M)    1        0      1           25.82     5100964  #FF1D15
# 3     BJP    1        0      1           16.68     3296354  #ff944d
# 4     KEC    1        0      1            1.38      272418  #097165
# 5     RSP    1        0      1            7.81     1543974  #4C2A87
