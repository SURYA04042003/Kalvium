# %% [markdown]
# Uttar Pradesh SP

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

url = "https://results.eci.gov.in/PcResultGenJune2024/partywisewinresult-1680S24.htm"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

table = soup.find('table', {'class': 'table table-striped table-bordered'})

data = []
for row in table.find_all('tr')[1:]:
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

df = pd.DataFrame(data, columns=['S.No', 'Parliament Constituency', 'Winning Candidate', 'Total Votes', 'Margin'])

# Create an Excel sheet
df.to_excel('partywisewinresult.xlsx', index=False)

# Create a pie chart using matplotlib
plt.pie(df['Total Votes'], labels=df['Parliament Constituency'], autopct='%1.1f%%')
plt.title('Party-wise Winning Results')
plt.show()

# %% [markdown]
# Uttar Pradesh BJP

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

url = "https://results.eci.gov.in/PcResultGenJune2024/partywisewinresult-369S24.htm"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

table = soup.find('table', {'class': 'table table-striped table-bordered'})

data = []
for row in table.find_all('tr')[1:]:
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

df = pd.DataFrame(data, columns=['S.No', 'Parliament Constituency', 'Winning Candidate', 'Total Votes', 'Margin'])

# Create an Excel sheet
df.to_excel('partywisewinresult.xlsx', index=False)

# Create a pie chart using matplotlib
plt.pie(df['Total Votes'], labels=df['Parliament Constituency'], autopct='%1.1f%%')
plt.title('Party-wise Winning Results')
plt.show()

# %% [markdown]
# Uttar Pradesh INC

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

url = "https://results.eci.gov.in/PcResultGenJune2024/partywisewinresult-742S24.htm"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

table = soup.find('table', {'class': 'table table-striped table-bordered'})

data = []
for row in table.find_all('tr')[1:]:
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

df = pd.DataFrame(data, columns=['S.No', 'Parliament Constituency', 'Winning Candidate', 'Total Votes', 'Margin'])

# Create an Excel sheet
df.to_excel('partywisewinresult.xlsx', index=False)

# Create a pie chart using matplotlib
plt.pie(df['Total Votes'], labels=df['Parliament Constituency'], autopct='%1.1f%%')
plt.title('Party-wise Winning Results')
plt.show()

# %% [markdown]
# Uttar Pradesh RLD

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

url = "https://results.eci.gov.in/PcResultGenJune2024/partywisewinresult-1458S24.htm"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

table = soup.find('table', {'class': 'table table-striped table-bordered'})

data = []
for row in table.find_all('tr')[1:]:
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

df = pd.DataFrame(data, columns=['S.No', 'Parliament Constituency', 'Winning Candidate', 'Total Votes', 'Margin'])

# Create an Excel sheet
df.to_excel('partywisewinresult.xlsx', index=False)

# Create a pie chart using matplotlib
plt.pie(df['Total Votes'], labels=df['Parliament Constituency'], autopct='%1.1f%%')
plt.title('Party-wise Winning Results')
plt.show()

# %% [markdown]
# Uttar Pradesh ASPKR

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

url = "https://results.eci.gov.in/PcResultGenJune2024/partywisewinresult-2989S24.htm"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

table = soup.find('table', {'class': 'table table-striped table-bordered'})

data = []
for row in table.find_all('tr')[1:]:
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

df = pd.DataFrame(data, columns=['S.No', 'Party', 'Number of Constituencies', 'Number of Seats Won', 'Total Votes'])

# Create an Excel sheet
df.to_excel('partywisewinresult.xlsx', index=False)

# Create a pie chart using matplotlib
plt.figure(figsize=(10,8))
plt.pie(df['Total Votes'].astype(int), labels=df['Party'], autopct='%1.1f%%')
plt.title('Party-wise Winning Results')
plt.show()

# %% [markdown]
# Uttar Pradesh ADAL

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

url = "https://results.eci.gov.in/PcResultGenJune2024/partywisewinresult-2070S24.htm"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

table = soup.find('table', {'class': 'table table-striped table-bordered'})

data = []
for row in table.find_all('tr')[1:]:
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

df = pd.DataFrame(data, columns=['S.No', 'Party', 'Number of Constituencies', 'Number of Seats Won', 'Total Votes'])

# Create an Excel sheet
df.to_excel('partywisewinresult.xlsx', index=False)

# Create a pie chart using matplotlib
plt.figure(figsize=(10,8))
plt.pie(df['Total Votes'].astype(int), labels=df['Party'], autopct='%1.1f%%')
plt.title('Party-wise Winning Results')
plt.show()
